# %% [markdown]
# ### Часть первая. Векторизация

# %%
# Подключение Google-диска
from google.colab import drive
drive.mount('/content/mount')
# Out:
# Mounted at /content/mount

# %%
# Установка необходимых пакетов
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.net.biocad.ru, https://pypi.org/simple
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 511 kB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (4.16.2)
# Requirement already satisfied: tqdm in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (1.10.2)
# Collecting torchvision
#   Downloading torchvision-0.12.0-cp38-cp38-macosx_10_9_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.2 MB/s
# Requirement already satisfied: numpy in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (1.21.2)
# Requirement already satisfied: scikit-learn in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: scipy in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: nltk in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp38-cp38-macosx_10_6_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 981 kB/s
# Requirement already satisfied: huggingface-hub in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from sentence_transformers) (0.4.0)
# Requirement already satisfied: typing-extensions in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->sentence_transformers) (3.7.4.3)
# Requirement already satisfied: filelock in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (5.3.1)
# Requirement already satisfied: sacremoses in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.49)
# Requirement already satisfied: requests in /Users/mikhaillebedev/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.3.15)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.11.6)
# Requirement already satisfied: packaging>=20.0 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Requirement already satisfied: joblib in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from nltk->sentence_transformers) (1.0.1)
# Requirement already satisfied: click in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from nltk->sentence_transformers) (8.0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from scikit-learn->sentence_transformers) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/mikhaillebedev/anaconda3/lib/python3.8/site-packages (from torchvision->sentence_transformers) (8.0.1)
# Collecting torch>=1.6.0
#   Downloading torch-1.11.0-cp38-none-macosx_10_9_x86_64.whl (129.9 MB)
#      |██████████████▍                 | 58.5 MB 538 kB/s eta 0:02:13

# %%
# Подключение библиотек
import numpy as np
import pandas as pd

import torch
import nltk
from sentence_transformers import models, SentenceTransformer

from tqdm import tqdm

# %%
# Вспомогательное
WINE_DATA_PATH = "/content/mount/MyDrive/Colab Notebooks/HSE/HSE NLP/wines_winestyle.csv"
MAIN_COLS = ["id", "name", "aroma", "taste", "food_pairing", "description"]
DESC_COLS = ["aroma", "taste", "food_pairing", "description"]

MODEL_INFO = "DeepPavlov/rubert-base-cased"

# %%
# Чтение данных
wine_df = pd.read_csv(WINE_DATA_PATH, usecols=MAIN_COLS)
wine_df
# Out:
#           id                                               name  \
# 0        116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1        117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2        118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3        119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4        120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...      ...                                                ...
# 43196  43490   Guilbaud Freres, "Coraline" Cabernet d'Anjou AOC
# 43197  43491                   Schlumberger, Gold Trocken, 2012
# 43198  43492          Derbent Wine Company, "Fanfara" Rose Brut
# 43199  43493                        "Blue Nun" 24K Gold Edition
# 43200  43494                        "Blue Nun" 24K Rose Edition
#
#                                                    aroma  \
# 0      Вино демонстрирует сложный аромат, сотканный и...
# 1      В глубоком аромате вина ноты вишни, сливы и еж...
# 2      Элегантный аромат вина раскрывается оттенками ...
# 3      Вино демонстрирует элегантный, сдержанный аром...
# 4      Вино демонстрирует глубокий аромат, сотканный ...
# ...                                                  ...
# 43196  Вино обладает тонким, изысканным ароматом с но...
# 43197  Игристое вино чарует освежающим ароматом с дом...
# 43198  Освежающий аромат вина наполнен утонченными но...
# 43199  Аромат вина раскрывается приятными и утонченны...
# 43200  Освежающий аромат вина изобилует нотками фруктов.
#
#                                                    taste  \
# 0      Вино обладает щедрым, ярким вкусом с оттенками...
# 1      Вино демонстрирует насыщенный, сбалансированны...
# 2      Вино демонстрирует округлый, сбалансированный ...
# 3      Вкус вина деликатный, мягкий и сбалансированны...
# 4      Вкус вина сочный, концентрированный, с оттенка...
# ...                                                  ...
# 43196  Вкус вина нежный, свежий, питкий, гладкий, сле...
# 43197  Игристое вино демонстрирует свежий, мягкий вку...
# 43198  Вкус вина легкий, обладает яркой и живой кисло...
# 43199  Вкус вина изысканный, сбалансированный, гармон...
# 43200  Вкус вина утонченный и сбалансированный, с при...
#
#                                             food_pairing  \
# 0      Вино составит гармоничную пару говядине, утке,...
# 1      Вино подходит к блюдам из говядины, телятины, ...
# 2      Вино подходит к блюдам из говядины, телятины, ...
# 3      Вино идеально подходит к блюдам из птицы, запе...
# 4      Вино рекомендуется употреблять с блюдами из мя...
# ...                                                  ...
# 43196  Вино прекрасно в качестве аперитива, в сочетан...
# 43197  Это изысканное вино рекомендуется подавать к д...
# 43198  Вино прекрасно сочетается с легкими закусками,...
# 43199  Вино идеально в качестве аперитива, хорошо соч...
# 43200  Вино идеально в качестве аперитива, хорошо соч...
#
#                                              description
# 0      "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1      Ramirez de la Piscina, Crianza, Rioja DOCa — к...
# 2      Ramirez de la Piscina, Reserva, Rioja DOCa — э...
# 3      Rafael Cambra, Soplo, Valencia DO — красное су...
# 4      Красное сухое вино "Drama" Red Blend, La Manch...
# ...                                                  ...
# 43196  "Coraline" Cabernet d'Anjou — очень приятное, ...
# 43197  Schlumberger, Gold Trocken — утонченное белое ...
# 43198  "Fanfara" Rose Brut — изысканное игристое вино...
# 43199  В 1857 году Герман Зихель основал небольшой би...
# 43200  В 1857 году Герман Зихель основал небольшой би...
#
# [43201 rows x 6 columns]

# %%
# Обработка пустых значений
wine_df[DESC_COLS] = wine_df[DESC_COLS].fillna("")

# %%
# Установка дополнительного nltk-модуля
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Токенизация
wine_df["tokens"] = ""
for index, row in wine_df.iterrows():
    full_desc = ""
    for col in DESC_COLS:
        full_desc += row[col] + " "
    wine_df.at[index, "tokens"] = nltk.tokenize.sent_tokenize(full_desc, language="russian")

# %%
# Отбор токенизированных данных
wine_tokens_df = wine_df[["id", "name", "tokens"]]
wine_tokens_df = wine_tokens_df[wine_tokens_df.tokens.map(len) > 0]
wine_tokens_df
# Out:
#           id                                               name  \
# 0        116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1        117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2        118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3        119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4        120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...      ...                                                ...
# 43196  43490   Guilbaud Freres, "Coraline" Cabernet d'Anjou AOC
# 43197  43491                   Schlumberger, Gold Trocken, 2012
# 43198  43492          Derbent Wine Company, "Fanfara" Rose Brut
# 43199  43493                        "Blue Nun" 24K Gold Edition
# 43200  43494                        "Blue Nun" 24K Rose Edition
#
#                                                   tokens
# 0      [Вино демонстрирует сложный аромат, сотканный ...
# 1      [В глубоком аромате вина ноты вишни, сливы и е...
# 2      [Элегантный аромат вина раскрывается оттенками...
# 3      [Вино демонстрирует элегантный, сдержанный аро...
# 4      [Вино демонстрирует глубокий аромат, сотканный...
# ...                                                  ...
# 43196  [Вино обладает тонким, изысканным ароматом с н...
# 43197  [Игристое вино чарует освежающим ароматом с до...
# 43198  [Освежающий аромат вина наполнен утонченными н...
# 43199  [Аромат вина раскрывается приятными и утонченн...
# 43200  [Освежающий аромат вина изобилует нотками фрук...
#
# [43190 rows x 3 columns]

# %%
# Создание (загрузка) модели
transformer = models.Transformer(MODEL_INFO)
pooling_module = models.Pooling(transformer.get_word_embedding_dimension())
model = SentenceTransformer(modules=[transformer, pooling_module])
# Out:
# Downloading:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.57M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# Переход на GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# cuda

# %%
# Векторизация
wine_tokens_df["vector"] = ""
for index, row in tqdm(wine_tokens_df.iterrows()):
    wine_tokens_df.at[index, "vector"] = model.encode(row["tokens"]).mean(axis=0).tolist()
# Out:
# 43190it [1:22:57,  8.68it/s]

# %%
# Сохранение векторизованных данных
wine_vectors = wine_tokens_df[["id", "name", "vector"]]
wine_vectors.to_csv("/content/mount/MyDrive/Colab Notebooks/HSE/HSE NLP/wines_vectors.csv", index=False)

# %% [markdown]
# ### Часть вторая. Рекомендация

# %%
# Подключение библиотек
import numpy as np
import pandas as pd

from sklearn.metrics.pairwise import cosine_similarity

# %%
# Вспомогательное
WINE_DATA_PATH = "../data/wine/wines_winestyle.csv"
MAIN_COLS = ["id", "name", "aroma", "taste", "food_pairing", "description"]

WINE_VEC_DATA_PATH = "../data/wine/wines_vectors.csv"

# %%
# Чтение стандартных данных
wine_df = pd.read_csv(WINE_DATA_PATH, usecols=MAIN_COLS)
wine_df
# Out:
#           id                                               name  \
# 0        116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1        117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2        118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3        119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4        120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...      ...                                                ...
# 43196  43490   Guilbaud Freres, "Coraline" Cabernet d'Anjou AOC
# 43197  43491                   Schlumberger, Gold Trocken, 2012
# 43198  43492          Derbent Wine Company, "Fanfara" Rose Brut
# 43199  43493                        "Blue Nun" 24K Gold Edition
# 43200  43494                        "Blue Nun" 24K Rose Edition
#
#                                                    aroma  \
# 0      Вино демонстрирует сложный аромат, сотканный и...
# 1      В глубоком аромате вина ноты вишни, сливы и еж...
# 2      Элегантный аромат вина раскрывается оттенками ...
# 3      Вино демонстрирует элегантный, сдержанный аром...
# 4      Вино демонстрирует глубокий аромат, сотканный ...
# ...                                                  ...
# 43196  Вино обладает тонким, изысканным ароматом с но...
# 43197  Игристое вино чарует освежающим ароматом с дом...
# 43198  Освежающий аромат вина наполнен утонченными но...
# 43199  Аромат вина раскрывается приятными и утонченны...
# 43200  Освежающий аромат вина изобилует нотками фруктов.
#
#                                                    taste  \
# 0      Вино обладает щедрым, ярким вкусом с оттенками...
# 1      Вино демонстрирует насыщенный, сбалансированны...
# 2      Вино демонстрирует округлый, сбалансированный ...
# 3      Вкус вина деликатный, мягкий и сбалансированны...
# 4      Вкус вина сочный, концентрированный, с оттенка...
# ...                                                  ...
# 43196  Вкус вина нежный, свежий, питкий, гладкий, сле...
# 43197  Игристое вино демонстрирует свежий, мягкий вку...
# 43198  Вкус вина легкий, обладает яркой и живой кисло...
# 43199  Вкус вина изысканный, сбалансированный, гармон...
# 43200  Вкус вина утонченный и сбалансированный, с при...
#
#                                             food_pairing  \
# 0      Вино составит гармоничную пару говядине, утке,...
# 1      Вино подходит к блюдам из говядины, телятины, ...
# 2      Вино подходит к блюдам из говядины, телятины, ...
# 3      Вино идеально подходит к блюдам из птицы, запе...
# 4      Вино рекомендуется употреблять с блюдами из мя...
# ...                                                  ...
# 43196  Вино прекрасно в качестве аперитива, в сочетан...
# 43197  Это изысканное вино рекомендуется подавать к д...
# 43198  Вино прекрасно сочетается с легкими закусками,...
# 43199  Вино идеально в качестве аперитива, хорошо соч...
# 43200  Вино идеально в качестве аперитива, хорошо соч...
#
#                                              description
# 0      "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1      Ramirez de la Piscina, Crianza, Rioja DOCa — к...
# 2      Ramirez de la Piscina, Reserva, Rioja DOCa — э...
# 3      Rafael Cambra, Soplo, Valencia DO — красное су...
# 4      Красное сухое вино "Drama" Red Blend, La Manch...
# ...                                                  ...
# 43196  "Coraline" Cabernet d'Anjou — очень приятное, ...
# 43197  Schlumberger, Gold Trocken — утонченное белое ...
# 43198  "Fanfara" Rose Brut — изысканное игристое вино...
# 43199  В 1857 году Герман Зихель основал небольшой би...
# 43200  В 1857 году Герман Зихель основал небольшой би...
#
# [43201 rows x 6 columns]

# %%
# Чтение векторизованных данных
wine_vectors_df = pd.read_csv(WINE_VEC_DATA_PATH)
wine_vectors_df
# Out:
#           id                                               name  \
# 0        116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1        117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2        118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3        119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4        120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...      ...                                                ...
# 43185  43490   Guilbaud Freres, "Coraline" Cabernet d'Anjou AOC
# 43186  43491                   Schlumberger, Gold Trocken, 2012
# 43187  43492          Derbent Wine Company, "Fanfara" Rose Brut
# 43188  43493                        "Blue Nun" 24K Gold Edition
# 43189  43494                        "Blue Nun" 24K Rose Edition
#
#                                                   vector
# 0      [0.20963743329048157, -0.2475746124982834, 0.2...
# 1      [0.24209600687026978, -0.1909744143486023, 0.3...
# 2      [0.22363285720348358, -0.2294279783964157, 0.3...
# 3      [0.32054412364959717, -0.23180171847343445, 0....
# 4      [0.16660216450691223, -0.1661527305841446, 0.2...
# ...                                                  ...
# 43185  [0.22548715770244598, -0.2360440045595169, 0.3...
# 43186  [-0.003142844419926405, -0.24957621097564697, ...
# 43187  [0.2338431179523468, -0.15624748170375824, 0.2...
# 43188  [0.14626814424991608, -0.2297821193933487, 0.3...
# 43189  [0.16030310094356537, -0.21668116748332977, 0....
#
# [43190 rows x 3 columns]

# %%
class Recommendator:
    def __init__(self, casual_df, vectors_df):
        self.casual_df = casual_df
        self.vectors_df = vectors_df
        self.vectors = np.concatenate(self.vectors_df["vector"].apply(self._get_vector))
        self.cosim_matrix = None # Для расчёта нужно большое кол-во ресурсов
        
    def _get_vector(self, s):
        res = s.strip("][").replace(" ", "").split(",")
        res = np.array([float(x) for x in res]).reshape(1, -1)
        return res
    
    def _calculate_cosim_matrix(self):
        self.cosim_matrix = cosine_similarity(vectors, vectors)
    
    def recommend_from_description(self, desc, n=10):
        pass # In progress
    
    def recommend_from_wine(self, wine_identifier, n=10):
        if isinstance(wine_identifier, int):
            idx = self.vectors_df[self.vectors_df["id"] == wine_identifier].index[0]
        elif isinstance(wine_identifier, str):
            idx = self.vectors_df[self.vectors_df["name"] == wine_identifier].index[0]
        
        cosim_vec = cosine_similarity(self.vectors[idx].reshape(1, -1), self.vectors)[0]
        best_idxs = np.argsort(cosim_vec)[::-1][:n+1]
        best_ids = self.vectors_df.iloc[best_idxs]["id"].tolist()
        
        recommendations = self.casual_df.iloc[pd.Index(self.casual_df["id"]).get_indexer(best_ids)]
        recommendations.reset_index(drop=True, inplace=True)
        return recommendations

# %%
# Инициализация рекомендательной системы
sommelier = Recommendator(wine_df, wine_vectors_df)

# %%
# Пример работы
def get_full_desc(wine_df, idx):
    wine = wine_df.iloc[idx]
    full_desc = f"\nName: {wine['name']}\n\n"
    full_desc += f"Description: {wine['description']}\n\n"
    full_desc += f"Aroma: {wine['aroma']}\n\n"
    full_desc += f"Taste: {wine['taste']}\n\n"
    full_desc += f"Food pairing: {wine['food_pairing']}\n\n"
    full_desc += f"{'='*127}"
    return full_desc

wine_identificator = 119 # "Rafael Cambra, Soplo, Valencia DO, 2014"
wine_identificator = 25467 # "Trimbach, Sylvaner, Alsace AOC"
rec = sommelier.recommend_from_wine(wine_identificator)

print(get_full_desc(rec, 0))
print(get_full_desc(rec, 1))

display(rec)
# Out:
# Name: Trimbach, Sylvaner, Alsace AOC
#
# Description: Trimbach, Sylvaner — традиционное белое сухое эльзасское вино, изготовленное из тщательно отобранного с виноградников в Рибонвилле винограда сорта Сильванер. После сбора плоды отделяются от стеблей, прессуются и ферментируются в резервуарах из нержавеющей стали, сохраняя сортовую свежесть и фруктовость. Потенциал хранения вина составляет около 5 лет. Винодельческое хозяйство Тримбах, существующее с 1626 года, — самый авторитетный производитель вин в Эльзасе. Сегодня семейным бизнесом управляют Юбер и Бернар Тримбахи, а также в делах активно участвуют младшие члены семьи — Жан и Пьер. Главной задачей виноделы считают сохранение респектабельного имиджа семейного предприятия. Кроме того, братья хотят поднять виноделие Эльзаса на невиданный до сих пор уровень. Нужно сказать, что пока они отлично справляются со своей работой — вина от Trimbach часто называют лучшими из лучших.
#
# Aroma: Свежий аромат вина наполнен деликатными фруктовыми и цветочными оттенками.
#
# Taste: Вино обладает сухим, легким, соблазнительным, освежающим вкусом с отличительными фруктовыми нотками.
#
# Food pairing: Вино идеально сочетается с запеканками, луковым тартом, моллюсками, рыбой-гриль, холодными мясными блюдами, традиционной эльзасской квашеной капустой и сосисками.
#
# ===============================================================================================================================
#
# Name: Trimbach, Pinot Blanc, Alsace AOC
#
# Description: Trimbach, Pinot Blanc — вино, которое доставит истинное удовольствие своим элегантным, освежающим, прекрасно сбалансированным вкусом. Оно изготавливается из рано созревающего винограда сорта Пино Блан, который после сбора отделяется от стеблей, прессуется и ферментируется в резервуарах из нержавеющей стали, сохраняя сортовую свежесть и выразительность. Сухое вино Пино Блан идеально подходит в качестве аперитива или в сочетании с легкими закусками как в повседневной жизни, так и на официальных обедах и приемах. Потенциал хранения вина составляет не менее 5-6 лет. Винодельческое хозяйство Тримбах, существующее с 1626 года, — самый авторитетный производитель вин в Эльзасе. Сегодня семейным бизнесом управляют Юбер и Бернар Тримбахи, а также в делах активно участвуют младшие члены семьи — Жан и Пьер. Главной задачей виноделы считают сохранение респектабельного имиджа семейного предприятия. Кроме того, братья хотят поднять виноделие Эльзаса на невиданный до сих пор уровень. Нужно сказать, что пока они отлично справляются со своей работой — вина от Trimbach часто называют лучшими из лучших.
#
# Aroma: Аромат вина наполнен заманчивыми фруктовыми оттенками.
#
# Taste: Вино обладает сухим, хорошо сбалансированным, эластичным и освежающим вкусом с хорошей кислотностью.
#
# Food pairing: Вино идеально в качестве аперитива в летнее время, в сочетании с различными салатами и закусками, холодными мясными деликатесами, морепродуктами (устрицами, моллюсками), рыбой-пашот с легким соусом из трав или синей форелью, пирогами, тартом фламбе.
#
# ===============================================================================================================================
#        id                                               name  \
# 0   25467                     Trimbach, Sylvaner, Alsace AOC
# 1   25630                  Trimbach, Pinot Blanc, Alsace AOC
# 2   29449             Trimbach, Riesling "Reserve" AOC, 2017
# 3    5602   Trimbach, Pinot Noir "Reserve", Alsace AOC, 2018
# 4   30314       Trimbach, Gewurztraminer "Reserve" AOC, 2013
# 5    8657  Trimbach, Riesling "Selection de Vieilles Vign...
# 6   28470                       Trimbach, Riesling AOC, 2018
# 7    1054                 Trimbach, Gewurztraminer AOC, 2016
# 8   28146         Trimbach, Gewurztraminer AOC, 2016, 375 мл
# 9    8527           Trimbach, Pinot Gris "Reserve" AOC, 2016
# 10  37178  Trimbach, Pinot Gris "Selection de Grains Nobl...
#
#                                                 aroma  \
# 0   Свежий аромат вина наполнен деликатными фрукто...
# 1   Аромат вина наполнен заманчивыми фруктовыми от...
# 2   Тонкий, свежий, аппетитный аромат вина раскрыв...
# 3   Вино демонстрирует приятный, щедрый аромат, со...
# 4   Аромат вина демонстрирует ноты корицы, мускатн...
# 5   Вино интригует мягким, гармоничным ароматом, с...
# 6   Свежий, изящный аромат вина наполнен тонами ци...
# 7   Вино обладает элегантным, свежим ароматом с от...
# 8   Вино обладает элегантным, свежим ароматом с от...
# 9   Вино обладает насыщенным ароматом с доминирующ...
# 10  Вино обладает приятным, свежим цветочным арома...
#
#                                                 taste  \
# 0   Вино обладает сухим, легким, соблазнительным, ...
# 1   Вино обладает сухим, хорошо сбалансированным, ...
# 2   Вкус вина сухой, свежий, яркий, с живой лимонн...
# 3   Вино привлекает сбалансированным фруктовым вку...
# 4   Вкус вина богатый, интенсивный, сочный, хорошо...
# 5   Вино демонстрирует мягкий, освежающий вкус с ф...
# 6   Вино демонстрирует гармоничный, чистый вкус с ...
# 7   Вино демонстрирует освежающий, мягкий вкус с ф...
# 8   Вино демонстрирует освежающий, мягкий вкус с ф...
# 9   Вино интригует богатым, освежающим вкусом с от...
# 10  Вино имеет богатый, насыщенный вкус с тонами ф...
#
#                                          food_pairing  \
# 0   Вино идеально сочетается с запеканками, луковы...
# 1   Вино идеально в качестве аперитива в летнее вр...
# 2   Вино прекрасно сочетается с кислой капустой, р...
# 3   Вино составит замечательную пару с мясом домаш...
# 4   Вино идеально в качестве аперитива, хорошо соч...
# 5   Вино можно употреблять в качестве аперитива, с...
# 6   Вино отлично в качестве аперитива, достойно со...
# 7   Вино идеально в качестве аперитива, хорошо соч...
# 8   Вино идеально в качестве аперитива, хорошо соч...
# 9   Вино является замечательным аперитивом, оно пр...
# 10  Вино прекрасно сочетается с фуа-гра, пряными б...
#
#                                           description
# 0   Trimbach, Sylvaner — традиционное белое сухое ...
# 1   Trimbach, Pinot Blanc — вино, которое доставит...
# 2   Trimbach, Riesling "Reserve" — элегантный, сух...
# 3   Pinot Noir "Reserve" — соблазнительное красное...
# 4   Trimbach, Gewurztraminer "Reserve" — округлое,...
# 5   Trimbach, Riesling "Selection de Vieilles Vign...
# 6   Рислинг по праву считается Королем Эльзаса и, ...
# 7   Гевюрцтраминер от хозяйства Тримбах — выразите...
# 8   Гевюрцтраминер от хозяйства Тримбах — выразите...
# 9   Виноград сорта Пино Гри происходит из Бургунди...
# 10  Пино Гри "Селексьон де Гран Нобль" — это белое...
