# %% [markdown]
# ### Часть первая. Векторизация

# %%
# Подключение библиотек
import numpy as np
import pandas as pd
import requests

import torch
import nltk
from sentence_transformers import models, SentenceTransformer
import os
import requests
from pathlib import Path
import nltk
from nltk import sent_tokenize, word_tokenize, regexp_tokenize
from nltk.corpus import stopwords
import pymorphy2
from collections import Counter

from tqdm import tqdm

url_stopwords_ru = "https://raw.githubusercontent.com/stopwords-iso/stopwords-ru/master/stopwords-ru.txt"
stopwords_ru = get_text(url_stopwords_ru).splitlines()
morph = pymorphy2.MorphAnalyzer()


def get_text(url, encoding='utf-8', to_lower=True):
    url = str(url)
    if url.startswith('http'):
        r = requests.get(url)
        if not r.ok:
            r.raise_for_status()
        return r.text.lower() if to_lower else r.text
    elif os.path.exists(url):
        with open(url, encoding=encoding) as f:
            return f.read().lower() if to_lower else f.read()
    else:
        raise Exception('parameter [url] can be either URL or a filename')
        

def normalize_tokens(tokens):
    return [morph.parse(tok)[0].normal_form for tok in tokens]


def remove_stopwords(tokens, stopwords=None, min_length=4):
    if not stopwords:
        return tokens
    stopwords = set(stopwords)
    tokens = [tok
              for tok in tokens
              if tok not in stopwords and len(tok) >= min_length]
    return tokens


def normalize_rem_stops(words, stopwords=None, normalize=True):
    if normalize:
        words = normalize_tokens(words)
    if stopwords:
        words = remove_stopwords(words, stopwords)
    return words


def prep_text(text):
    words = nltk.tokenize.word_tokenize(text, language="russian")
    words = normalize_rem_stops(words, stopwords=stopwords_ru)
    return words


def get_full_desc(wine_df, idx):
    wine = wine_df.iloc[idx]
    full_desc = f"\nName: {wine['name']}\n\n"
    full_desc += f"Aroma: {wine['aroma']}\n\n"
    full_desc += f"Taste: {wine['taste']}\n\n"
    full_desc += f"Food pairing: {wine['food_pairing']}\n\n"
    full_desc += f"{'='*127}"
    return full_desc

# %%
# Вспомогательное
WINE_DATA_PATH = "../data/wine/wines_winestyle.csv"
MAIN_COLS = ["id", "name", "aroma", "taste", "food_pairing", "description"]
DESC_COLS = ["aroma", "taste", "food_pairing"]

MODEL_INFO = "DeepPavlov/rubert-base-cased"

# %%
# Чтение данных
wine_df = pd.read_csv(WINE_DATA_PATH, usecols=MAIN_COLS)
wine_df = wine_df.head(10000)

# %%
# Обработка пустых значений
wine_df[DESC_COLS] = wine_df[DESC_COLS].fillna("")

# %%
# Установка дополнительного nltk-модуля
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /data/user/mikhaillebedev/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Токенизация
tokens_col = []
wine_df['full_desc'] = wine_df[DESC_COLS].agg(' '.join, axis=1)
wine_df["tokens"] = [prep_text(text) for text in tqdm(wine_df['full_desc'])]
# Out:
# 100%|██████████| 10000/10000 [02:19<00:00, 71.77it/s]

# %%
wine_df
# Out:
#          id                                               name  \
# 0       116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1       117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2       118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3       119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4       120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...     ...                                                ...
# 9995  10116  Moulin des Haies, Muscadet Sevre et Maine Sur ...
# 9996  10117                     "Greatwall" Cabernet Sauvignon
# 9997  10118                   Kumala, "Reserve" Pinotage, 2019
# 9998  10119       Echeverria, Cabernet Sauvignon Reserva, 2017
# 9999  10120          Echeverria, Sauvignon Blanc Reserva, 2018
#
#                                                   aroma  \
# 0     Вино демонстрирует сложный аромат, сотканный и...
# 1     В глубоком аромате вина ноты вишни, сливы и еж...
# 2     Элегантный аромат вина раскрывается оттенками ...
# 3     Вино демонстрирует элегантный, сдержанный аром...
# 4     Вино демонстрирует глубокий аромат, сотканный ...
# ...                                                 ...
# 9995  Чистый, свежий аромат вина отличается щедрость...
# 9996  Элегантный аромат вина раскрывается оттенками ...
# 9997  Вино привлекает элегантным ароматом с доминиру...
# 9998  Вино обладает гармоничным, щедрым ароматом, со...
# 9999  Свежий аромат вина изобилует оттенками грейпфр...
#
#                                                   taste  \
# 0     Вино обладает щедрым, ярким вкусом с оттенками...
# 1     Вино демонстрирует насыщенный, сбалансированны...
# 2     Вино демонстрирует округлый, сбалансированный ...
# 3     Вкус вина деликатный, мягкий и сбалансированны...
# 4     Вкус вина сочный, концентрированный, с оттенка...
# ...                                                 ...
# 9995  Вино обладает довольно насыщенным вкусом, в ко...
# 9996  Вкус вина мягкий, округлый, с фруктово-ягодным...
# 9997  Вино демонстрирует мягкий, чистый вкус с фрукт...
# 9998  Вино интригует гладким, хорошо структурированн...
# 9999  Вкус вина мягкий, освежающий, с хорошо сбаланс...
#
#                                            food_pairing  \
# 0     Вино составит гармоничную пару говядине, утке,...
# 1     Вино подходит к блюдам из говядины, телятины, ...
# 2     Вино подходит к блюдам из говядины, телятины, ...
# 3     Вино идеально подходит к блюдам из птицы, запе...
# 4     Вино рекомендуется употреблять с блюдами из мя...
# ...                                                 ...
# 9995  Вино составит хорошее сочетание с морепродукта...
# 9996  Вино лучше всего подавать к жареному или тушен...
# 9997  Вино идеально подходит к трапезе, лучше всего ...
# 9998  Вино составит прекрасную пару со зрелыми сырам...
# 9999  Вино идеально сочетается с морепродуктами, блю...
#
#                                             description  \
# 0     "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1     Ramirez de la Piscina, Crianza, Rioja DOCa — к...
# 2     Ramirez de la Piscina, Reserva, Rioja DOCa — э...
# 3     Rafael Cambra, Soplo, Valencia DO — красное су...
# 4     Красное сухое вино "Drama" Red Blend, La Manch...
# ...                                                 ...
# 9995  Moulin des Haies, Muscadet Sevre et Maine Sur ...
# 9996  "Greatwall" Cabernet Sauvignon — китайское кра...
# 9997  Kumala, "Reserve" Pinotage изготовлено из трад...
# 9998  Cabernet Sauvignon Reserva — одно из элегантны...
# 9999  Sauvignon Blanc Reserva от компании Эчеверрия ...
#
#                                               full_desc  \
# 0     Вино демонстрирует сложный аромат, сотканный и...
# 1     В глубоком аромате вина ноты вишни, сливы и еж...
# 2     Элегантный аромат вина раскрывается оттенками ...
# 3     Вино демонстрирует элегантный, сдержанный аром...
# 4     Вино демонстрирует глубокий аромат, сотканный ...
# ...                                                 ...
# 9995  Чистый, свежий аромат вина отличается щедрость...
# 9996  Элегантный аромат вина раскрывается оттенками ...
# 9997  Вино привлекает элегантным ароматом с доминиру...
# 9998  Вино обладает гармоничным, щедрым ароматом, со...
# 9999  Свежий аромат вина изобилует оттенками грейпфр...
#
#                                                  tokens
# 0     [вино, демонстрировать, сложный, аромат, сотка...
# 1     [глубокий, аромат, вино, нота, вишня, слив, еж...
# 2     [элегантный, аромат, вино, раскрываться, оттен...
# 3     [вино, демонстрировать, элегантный, сдержать, ...
# 4     [вино, демонстрировать, глубокий, аромат, сотк...
# ...                                                 ...
# 9995  [чистый, свежий, аромат, вино, отличаться, щед...
# 9996  [элегантный, аромат, вино, раскрываться, оттен...
# 9997  [вино, привлекать, элегантный, аромат, доминир...
# 9998  [вино, обладать, гармоничный, щедрый, аромат, ...
# 9999  [свежий, аромат, вино, изобиловать, оттенок, г...
#
# [10000 rows x 8 columns]

# %%
# Отбор токенизированных данных
wine_tokens_df = wine_df[["id", "name", "tokens"]]
wine_tokens_df = wine_tokens_df[wine_tokens_df.tokens.map(len) > 0]
wine_tokens_df
# Out:
#          id                                               name  \
# 0       116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1       117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2       118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3       119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4       120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...     ...                                                ...
# 9995  10116  Moulin des Haies, Muscadet Sevre et Maine Sur ...
# 9996  10117                     "Greatwall" Cabernet Sauvignon
# 9997  10118                   Kumala, "Reserve" Pinotage, 2019
# 9998  10119       Echeverria, Cabernet Sauvignon Reserva, 2017
# 9999  10120          Echeverria, Sauvignon Blanc Reserva, 2018
#
#                                                  tokens
# 0     [вино, демонстрировать, сложный, аромат, сотка...
# 1     [глубокий, аромат, вино, нота, вишня, слив, еж...
# 2     [элегантный, аромат, вино, раскрываться, оттен...
# 3     [вино, демонстрировать, элегантный, сдержать, ...
# 4     [вино, демонстрировать, глубокий, аромат, сотк...
# ...                                                 ...
# 9995  [чистый, свежий, аромат, вино, отличаться, щед...
# 9996  [элегантный, аромат, вино, раскрываться, оттен...
# 9997  [вино, привлекать, элегантный, аромат, доминир...
# 9998  [вино, обладать, гармоничный, щедрый, аромат, ...
# 9999  [свежий, аромат, вино, изобиловать, оттенок, г...
#
# [10000 rows x 3 columns]

# %%
# Создание (загрузка) модели
transformer = models.Transformer(MODEL_INFO)
pooling_module = models.Pooling(transformer.get_word_embedding_dimension())
model = SentenceTransformer(modules=[transformer, pooling_module])
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#  84%|████████▎ | 836/1000 [15:36<03:03,  1.12s/it]

# %%
# Переход на GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# cuda

# %%
wine_vectors = [model.encode(token).mean(axis=0).tolist() for token in tqdm(wine_tokens_df["tokens"])]
wine_tokens_df["vector"] = wine_vectors
# Out:
# 100%|██████████| 10000/10000 [05:40<00:00, 29.34it/s]

# %%
# Сохранение векторизованных данных
wine_vectors_df = wine_tokens_df[["id", "name", "vector"]]
wine_vectors_df.to_csv("../data/wine/wines_vectors_local.csv", index=False)
wine_vectors_df.to_parquet('../data/wine/wines_vectors.parquet', index=False) 
wine_df.to_csv("../data/wine/wines_winestyle_10k.csv", index=False)

# %% [markdown]
# ### Часть вторая. Рекомендация

# %%
# Подключение библиотек
import numpy as np
import pandas as pd
from ast import literal_eval

from sklearn.metrics.pairwise import cosine_similarity

# %%
# Вспомогательное
WINE_DATA_PATH = "../data/wine/wines_winestyle.csv"
MAIN_COLS = ["id", "name", "aroma", "taste", "food_pairing", "description"]

WINE_VEC_DATA_PATH = "../data/wine/wines_vectors.parquet"

# %%
# Чтение стандартных данных
wine_df = pd.read_csv(WINE_DATA_PATH, usecols=MAIN_COLS)
wine_df
# Out:
#           id                                               name  \
# 0        116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1        117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2        118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3        119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4        120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...      ...                                                ...
# 43196  43490   Guilbaud Freres, "Coraline" Cabernet d'Anjou AOC
# 43197  43491                   Schlumberger, Gold Trocken, 2012
# 43198  43492          Derbent Wine Company, "Fanfara" Rose Brut
# 43199  43493                        "Blue Nun" 24K Gold Edition
# 43200  43494                        "Blue Nun" 24K Rose Edition
#
#                                                    aroma  \
# 0      Вино демонстрирует сложный аромат, сотканный и...
# 1      В глубоком аромате вина ноты вишни, сливы и еж...
# 2      Элегантный аромат вина раскрывается оттенками ...
# 3      Вино демонстрирует элегантный, сдержанный аром...
# 4      Вино демонстрирует глубокий аромат, сотканный ...
# ...                                                  ...
# 43196  Вино обладает тонким, изысканным ароматом с но...
# 43197  Игристое вино чарует освежающим ароматом с дом...
# 43198  Освежающий аромат вина наполнен утонченными но...
# 43199  Аромат вина раскрывается приятными и утонченны...
# 43200  Освежающий аромат вина изобилует нотками фруктов.
#
#                                                    taste  \
# 0      Вино обладает щедрым, ярким вкусом с оттенками...
# 1      Вино демонстрирует насыщенный, сбалансированны...
# 2      Вино демонстрирует округлый, сбалансированный ...
# 3      Вкус вина деликатный, мягкий и сбалансированны...
# 4      Вкус вина сочный, концентрированный, с оттенка...
# ...                                                  ...
# 43196  Вкус вина нежный, свежий, питкий, гладкий, сле...
# 43197  Игристое вино демонстрирует свежий, мягкий вку...
# 43198  Вкус вина легкий, обладает яркой и живой кисло...
# 43199  Вкус вина изысканный, сбалансированный, гармон...
# 43200  Вкус вина утонченный и сбалансированный, с при...
#
#                                             food_pairing  \
# 0      Вино составит гармоничную пару говядине, утке,...
# 1      Вино подходит к блюдам из говядины, телятины, ...
# 2      Вино подходит к блюдам из говядины, телятины, ...
# 3      Вино идеально подходит к блюдам из птицы, запе...
# 4      Вино рекомендуется употреблять с блюдами из мя...
# ...                                                  ...
# 43196  Вино прекрасно в качестве аперитива, в сочетан...
# 43197  Это изысканное вино рекомендуется подавать к д...
# 43198  Вино прекрасно сочетается с легкими закусками,...
# 43199  Вино идеально в качестве аперитива, хорошо соч...
# 43200  Вино идеально в качестве аперитива, хорошо соч...
#
#                                              description
# 0      "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1      Ramirez de la Piscina, Crianza, Rioja DOCa — к...
# 2      Ramirez de la Piscina, Reserva, Rioja DOCa — э...
# 3      Rafael Cambra, Soplo, Valencia DO — красное су...
# 4      Красное сухое вино "Drama" Red Blend, La Manch...
# ...                                                  ...
# 43196  "Coraline" Cabernet d'Anjou — очень приятное, ...
# 43197  Schlumberger, Gold Trocken — утонченное белое ...
# 43198  "Fanfara" Rose Brut — изысканное игристое вино...
# 43199  В 1857 году Герман Зихель основал небольшой би...
# 43200  В 1857 году Герман Зихель основал небольшой би...
#
# [43201 rows x 6 columns]

# %%
# Чтение векторизованных данных
wine_vectors_df = pd.read_parquet(WINE_VEC_DATA_PATH)
wine_vectors_df
# Out:
#          id                                               name  \
# 0       116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...
# 1       117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015
# 2       118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014
# 3       119            Rafael Cambra, Soplo, Valencia DO, 2014
# 4       120  Familia Bastida, "Drama" Red Blend, La Mancha ...
# ...     ...                                                ...
# 9995  10116  Moulin des Haies, Muscadet Sevre et Maine Sur ...
# 9996  10117                     "Greatwall" Cabernet Sauvignon
# 9997  10118                   Kumala, "Reserve" Pinotage, 2019
# 9998  10119       Echeverria, Cabernet Sauvignon Reserva, 2017
# 9999  10120          Echeverria, Sauvignon Blanc Reserva, 2018
#
#                                                  vector
# 0     [0.19545800983905792, 0.22112557291984558, 0.1...
# 1     [0.20425255596637726, 0.21205838024616241, 0.2...
# 2     [0.2254984825849533, 0.21893933415412903, 0.19...
# 3     [0.21787668764591217, 0.21199947595596313, 0.1...
# 4     [0.20609961450099945, 0.2198144942522049, 0.18...
# ...                                                 ...
# 9995  [0.1838761270046234, 0.19599491357803345, 0.15...
# 9996  [0.24622108042240143, 0.22963517904281616, 0.1...
# 9997  [0.19348041713237762, 0.195719376206398, 0.161...
# 9998  [0.23446586728096008, 0.20856806635856628, 0.1...
# 9999  [0.1972392201423645, 0.21575118601322174, 0.13...
#
# [10000 rows x 3 columns]

# %%
import itertools

class Recommendator:
    def __init__(self, casual_df, vectors_df):
        self.casual_df = casual_df
        self.vectors_df = vectors_df
        self.vectors = np.concatenate(self.vectors_df["vector"]).reshape((wine_vectors_df.shape[0], -1))
        self.cosim_matrix = None # Для расчёта нужно большое кол-во ресурсов

    def _calculate_cosim_matrix(self):
        self.cosim_matrix = cosine_similarity(vectors, vectors)
    
    def get_jaccard_sim(self, set1, set2): 
        c = set1.intersection(set2)
        return c, float(len(c)) / (len(set1) + len(set2) - len(c))
    
    def recommend_from_description(self, desc, n=10):
        wine_vector = model.encode(prep_text(desc)).mean(axis=0).tolist()
        cosim_vec = cosine_similarity(np.array(wine_vector).reshape(1, -1), self.vectors)[0]
        best_idxs = np.argsort(cosim_vec)[::-1][:n+1]
        best_ids = self.vectors_df.iloc[best_idxs]["id"].tolist()
        
        recommendations = self.casual_df.iloc[pd.Index(self.casual_df["id"]).get_indexer(best_ids)]
        recommendations.reset_index(drop=True, inplace=True)
        return recommendations
    
    def recommend_from_wine(self, wine_identifier, n=10):
        if isinstance(wine_identifier, int):
            idx = self.vectors_df[self.vectors_df["id"] == wine_identifier].index[0]
        elif isinstance(wine_identifier, str):
            idx = self.vectors_df[self.vectors_df["name"] == wine_identifier].index[0]
        
        cosim_vec = cosine_similarity(self.vectors[idx].reshape(1, -1), self.vectors)[0]
        best_idxs = np.argsort(cosim_vec)[::-1][:n+1]
        best_ids = self.vectors_df.iloc[best_idxs]["id"].tolist()
        
        recommendations = self.casual_df.iloc[pd.Index(self.casual_df["id"]).get_indexer(best_ids)]
        recommendations.reset_index(drop=True, inplace=True)
        recommend_tokens = set(tuple(itertools.chain(*recommendations["tokens"])))
        
        query_tokens = set(recommendations["tokens"][0])
        
        random_wines = self.casual_df.iloc[pd.Index(self.casual_df["id"]).get_indexer(np.random.randint(1, 
                                                                                                        self.casual_df.shape[0], 
                                                                                                        n))]
        random_wines.reset_index(drop=True, inplace=True)
        random_tokens = set(tuple(itertools.chain(*random_wines["tokens"])))
        matched_recommended, rec_jacc = self.get_jaccard_sim(query_tokens, recommend_tokens)
        matched_random, rand_jacc = self.get_jaccard_sim(query_tokens, random_tokens)
        print("similarity in recommended: ", "{0:0.2f}".format(rec_jacc))
        print("similarity in random: ", "{0:0.2f}".format(rand_jacc))
        print("matched tokens in recommended: ", matched_recommended)
        print("matched tokens in random: ", matched_random)
        return recommendations

# %%
# Инициализация рекомендательной системы
sommelier = Recommendator(wine_df, wine_vectors_df)

# %%
# Пример работы
# wine_identificator = 119 
wine_identificator = "Rafael Cambra, Soplo, Valencia DO, 2014"

# wine_identificator = 25467 # "Trimbach, Sylvaner, Alsace AOC"
rec = sommelier.recommend_from_wine(wine_identificator)

print(get_full_desc(rec, 0))
print(get_full_desc(rec, 1))

display(rec)
# Out:
# similarity in recommended:  0.21
# similarity in random:  0.11
# matched tokens in recommended:  {'сбалансированный', 'вкус', 'нота', 'птица', 'элегантный', 'запечь', 'деликатный', 'соткать', 'мясо', 'мягкий', 'демонстрировать', 'фрукт', 'аромат', 'тонкий', 'идеально', 'цвет', 'вино', 'танин', 'подходить', 'спелый', 'приятный', 'блюдо', 'послевкусие', 'сдержать'}
# matched tokens in random:  {'идеально', 'сбалансированный', 'мягкий', 'цвет', 'вино', 'элегантный', 'демонстрировать', 'танин', 'спелый', 'приятный', 'блюдо', 'запечь', 'деликатный', 'послевкусие', 'вкус', 'фрукт', 'мясо', 'аромат', 'нота', 'тонкий'}
#
# Name: Rafael Cambra, Soplo, Valencia DO, 2014
#
# Aroma: Вино демонстрирует элегантный, сдержанный аромат, сотканный из нот спелых фруктов и цветов.
#
# Taste: Вкус вина деликатный, мягкий и сбалансированный, с тонкими танинами и приятным послевкусием.
#
# Food pairing: Вино идеально подходит к блюдам из птицы, запеченного мяса и сырам.
#
# ===============================================================================================================================
#
# Name: Chateau de Beauregard, Fleurie "Colonies de Rochegres" AOC, 2014
#
# Aroma: Вино демонстрирует элегантный аромат, сотканный из нот спелых темных фруктов, пряностей и минералов.
#
# Taste: Вкус вина округлый, сбалансированный, с фруктово-пряными оттенками и мягкими танинами в продолжительном послевкусии.
#
# Food pairing: Вино рекомендуют подавать к козьему сыру, блюдам из красного мяса и мяса птицы.
#
# ===============================================================================================================================
#       id                                               name  \
# 0    119            Rafael Cambra, Soplo, Valencia DO, 2014
# 1   6625  Chateau de Beauregard, Fleurie "Colonies de Ro...
# 2   6198  Undurraga, "Aliwen" Cabernet Sauvignon-Syrah R...
# 3   1631                         "Tussock Jumper" Carmenere
# 4   1776  Derbent Wine Company, "Di Caspico" Cabernet Sa...
# 5   4934   Fontanafredda, Barolo DOCG, 2014, gif box, 1.5 л
# 6   4096  Domaine Saint-Lannes, "Les Peyrades", Cotes de...
# 7   9549                        "Chatelain Louis" Rouge Sec
# 8   9470                          "Tierra Santa" Tinto Seco
# 9   2065         Covinca, "Vina Oria" Garnacha, Carinena DO
# 10  9984             "Estreia" Tinto, Vinho Verde DOC, 2019
#
#                                                 aroma  \
# 0   Вино демонстрирует элегантный, сдержанный аром...
# 1   Вино демонстрирует элегантный аромат, сотканны...
# 2   Интенсивный, сложный, сочный аромат вина гармо...
# 3   Вино обладает великолепным ароматом, который с...
# 4   Вино демонстрирует элегантный, гармоничный аро...
# 5   Вино демонстрирует сложный аромат, сотканный и...
# 6   Вино демонстрирует гармоничный аромат с домини...
# 7   Вино соблазняет приятным, утонченным ароматом ...
# 8   Вино отличается ярким и запоминающимся аромато...
# 9   Вино обладает элегантным, утонченным ароматом ...
# 10  Вино демонстрирует элегантный аромат, сотканны...
#
#                                                 taste  \
# 0   Вкус вина деликатный, мягкий и сбалансированны...
# 1   Вкус вина округлый, сбалансированный, с фрукто...
# 2   Вкус вина хорошо сбалансированный, с мощными, ...
# 3   Вино покоряет мощным, богатым, великолепно сба...
# 4   Вкус вина мягкий, округлый, со сбалансированно...
# 5   Вкус вина полный, округлый, с оттенками вишни,...
# 6   Вкус вина мягкий, сбалансированный, с фруктовы...
# 7   Вкус вина округлый, мягкий, свежий, с сочными ...
# 8   Вино обладает мягким, приятным, питким, фрукто...
# 9   Вино демонстрирует выразительный, насыщенный в...
# 10  Вино привлекает округлым, сбалансированным вку...
#
#                                          food_pairing  \
# 0   Вино идеально подходит к блюдам из птицы, запе...
# 1   Вино рекомендуют подавать к козьему сыру, блюд...
# 2   Вино превосходно сочетается с блюдами из красн...
# 3   Вино идеально сочетается с блюдами средиземном...
# 4   Вино гармонично сочетается с легкими закусками...
# 5   Вино великолепно сочетается с дичью, богатыми ...
# 6   Вино отлично сочетается с приготовленным на гр...
# 7   Вино станет прекрасным сопровождением блюд из ...
# 8   Вино создаст отличную гастрономическую пару с ...
# 9   Вино сочетается со многими блюдами, особенно у...
# 10  Вино составит прекрасную пару холодным мясным ...
#
#                                           description  \
# 0   Rafael Cambra, Soplo, Valencia DO — красное су...
# 1   Chateau de Beauregard, Fleurie "Colonies de Ro...
# 2   Aliwen — линейка вин, воплощающая в себе мисти...
# 3   "Tussock Jumper" является премиальным винным б...
# 4   Вина линейки "Di Caspico" — гордость каспийско...
# 5   Fontanafredda, Barolo — яркое, сочное вино с п...
# 6   Domaine Saint-Lannes, "Les Peyrades" — красное...
# 7   "Chatelain Louis" Rouge Sec — свежее французск...
# 8   "Tierra Santa" Tinto Seco — яркое красное сухо...
# 9   "Vina Oria" Garnacha — красное сухое вино, соз...
# 10  "Estreia" Tinto — полусухое красное вино, созд...
#
#                                             full_desc  \
# 0   Вино демонстрирует элегантный, сдержанный аром...
# 1   Вино демонстрирует элегантный аромат, сотканны...
# 2   Интенсивный, сложный, сочный аромат вина гармо...
# 3   Вино обладает великолепным ароматом, который с...
# 4   Вино демонстрирует элегантный, гармоничный аро...
# 5   Вино демонстрирует сложный аромат, сотканный и...
# 6   Вино демонстрирует гармоничный аромат с домини...
# 7   Вино соблазняет приятным, утонченным ароматом ...
# 8   Вино отличается ярким и запоминающимся аромато...
# 9   Вино обладает элегантным, утонченным ароматом ...
# 10  Вино демонстрирует элегантный аромат, сотканны...
#
#                                                tokens
# 0   [вино, демонстрировать, элегантный, сдержать, ...
# 1   [вино, демонстрировать, элегантный, аромат, со...
# 2   [интенсивный, сложный, сочный, аромат, вино, г...
# 3   [вино, обладать, великолепный, аромат, соткать...
# 4   [вино, демонстрировать, элегантный, гармоничны...
# 5   [вино, демонстрировать, сложный, аромат, сотка...
# 6   [вино, демонстрировать, гармоничный, аромат, д...
# 7   [вино, соблазнять, приятный, утончить, аромат,...
# 8   [вино, отличаться, яркий, запоминаться, аромат...
# 9   [вино, обладать, элегантный, утончить, аромат,...
# 10  [вино, демонстрировать, элегантный, аромат, со...

# %%
# rec = sommelier.recommend_from_description("кислое маслянистое горькое")
rec = sommelier.recommend_from_description("спелая вишня и травяной запах")

print(get_full_desc(rec, 0))
print(get_full_desc(rec, 1))

display(rec)
# Out:
# Name: Zonin, Valpolicella DOC
#
# Aroma: Аромат вина наполнен фруктово-ягодными нотами ежевики и спелой вишни.
#
# Taste: Вкус вина свежий, с мягкой текстурой и заманчивыми вишневыми нотками.
#
# Food pairing: Вино хорошо сочетается с неострыми мясными блюдами, макаронами с мясным соусом и зрелыми сырами.
#
# ===============================================================================================================================
#
# Name: Cusumano, "Jale" Chardonnay, Sicilia DOC, 2018
#
# Aroma: Сложный аромат вина наполнен нотками спелых желтых фруктов (цитрусовых, дыни, папайи), тостов, ванили, сушеного абрикоса и маслянистыми ореховыми оттенками.
#
# Taste: Вкус вина богатый, хорошо сбалансированный и структурированный, с тонкой кислотностью и долгим, гладким, элегантным послевкусием.
#
# Food pairing: Вино прекрасно сочетается со всеми рыбными блюдами, белым мясом под сливочным соусом, грибным ризотто, пастой с пряными травами, молодыми и зрелыми сырами.
#
# ===============================================================================================================================
#        id                                               name  \
# 0    6264                            Zonin, Valpolicella DOC
# 1    1987     Cusumano, "Jale" Chardonnay, Sicilia DOC, 2018
# 2    5278                         Sophenia, "Altosur" Malbec
# 3    5177            Гранд Резерв "Атаман" Цимлянский Черный
# 4    3801        "Marques de Casa Concha" Cabernet Sauvignon
# 5    1999                             "Хороший Год" Бастардо
# 6    2674                   "Легенды Ай-Петри" Тамянка Южная
# 7   10010                "Duke of Wellington" Pinotage, 2017
# 8    4918  Domaine de Pignan, Coralie et Floriane, Chatea...
# 9     752              Массандра, Портвейн красный "Ливадия"
# 10    354  Lar de Paula, Tempranillo Reserva, Rioja DOC, ...
#
#                                                 aroma  \
# 0   Аромат вина наполнен фруктово-ягодными нотами ...
# 1   Сложный аромат вина наполнен нотками спелых же...
# 2   Аромат вина наполнен насыщенными тонами спелых...
# 3   В аромате вина первыми выступают железистые и ...
# 4   В букете вина сочные ароматы вишни, смородины ...
# 5   Утонченный и соблазнительный аромат вина окуты...
# 6   Тонкий аромат вина сложен из нот спелых садовы...
# 7   Элегантный аромат вина окутывает тонами сливы,...
# 8   Соблазнительный аромат вина изобилует нотами с...
# 9   Аромат вина комплексный, насыщенный и нежный о...
# 10  Довольно мощный и интенсивный аромат вина раск...
#
#                                                 taste  \
# 0   Вкус вина свежий, с мягкой текстурой и заманчи...
# 1   Вкус вина богатый, хорошо сбалансированный и с...
# 2   Вкус вина интенсивный, концентрированный, слад...
# 3   Вкус вина понятный, не слишком сложный, с умер...
# 4   Вкус вина концентрированный, с шелковистой тан...
# 5   Вино отличается изысканным, гармоничным, отлич...
# 6   Вкус вина гармоничный, чистый, фруктовый, с но...
# 7   Вкус вина гармоничный, сочный, теплый, с делик...
# 8   Вино отличается многогранным, мощным, изысканн...
# 9   Вкус вина гармоничный, согревающий, умеренно т...
# 10  Вкус вина элегантный, хорошо структурированный...
#
#                                          food_pairing  \
# 0   Вино хорошо сочетается с неострыми мясными блю...
# 1   Вино прекрасно сочетается со всеми рыбными блю...
# 2   Вино прекрасно сочетается со стейком из говяди...
# 3   Вино хорошо сочетается с красным мясом, дичью,...
# 4   Вино хорошо сочетается с красным мясом, зрелым...
# 5   Вино идеально гармонирует с мясными блюдами, м...
# 6   Вино рекомендуется сочетать с рыбой, сырами с ...
# 7   Вино можно сочетать с блюдами с томатным соусо...
# 8   Вино отлично сочетается с запеченой уткой, жар...
# 9   Вино прекрасно как дижестив, а также хорошо со...
# 10  Вино хорошо сочетается с жареным или тушеным м...
#
#                                           description  \
# 0   Zonin, Valpolicella — красное вино из линейки ...
# 1   Близ Палермо есть район под названием Джале, с...
# 2   Название линейки вин "Altosur" означает "Высок...
# 3   Гранд Резерв "Атаман" Цимлянский Черный — крас...
# 4   "Marques de Casa Concha" — один из лучших брен...
# 5   "Хороший Год" Бастардо — красное сухое вино из...
# 6   Линейка столовых вин "Легенды Ай-Петри", созда...
# 7   "Duke of Wellington" Pinotage является сердцем...
# 8   Domaine de Pignan, Coralie et Floriane, Chatea...
# 9   Портвейн красный "Ливадия" производят из виног...
# 10  Tempranillo Reserva — щедрое, насыщенное вино ...
#
#                                             full_desc  \
# 0   Аромат вина наполнен фруктово-ягодными нотами ...
# 1   Сложный аромат вина наполнен нотками спелых же...
# 2   Аромат вина наполнен насыщенными тонами спелых...
# 3   В аромате вина первыми выступают железистые и ...
# 4   В букете вина сочные ароматы вишни, смородины ...
# 5   Утонченный и соблазнительный аромат вина окуты...
# 6   Тонкий аромат вина сложен из нот спелых садовы...
# 7   Элегантный аромат вина окутывает тонами сливы,...
# 8   Соблазнительный аромат вина изобилует нотами с...
# 9   Аромат вина комплексный, насыщенный и нежный о...
# 10  Довольно мощный и интенсивный аромат вина раск...
#
#                                                tokens
# 0   [аромат, вино, наполнить, фруктово-ягодный, но...
# 1   [сложный, аромат, вино, наполнить, нотка, спел...
# 2   [аромат, вино, наполнить, насыщенный, спелый, ...
# 3   [аромат, вино, выступать, железистый, животное...
# 4   [букет, вино, сочный, аромат, вишня, смородина...
# 5   [утончить, соблазнительный, аромат, вино, окут...
# 6   [тонкий, аромат, вино, сложный, нота, спелый, ...
# 7   [элегантный, аромат, вино, окутывать, слив, ви...
# 8   [соблазнительный, аромат, вино, изобиловать, н...
# 9   [аромат, вино, комплексный, насыщенный, нежный...
# 10  [мощный, интенсивный, аромат, вино, раскрывать...
